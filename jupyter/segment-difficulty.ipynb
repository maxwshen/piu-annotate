# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv('/home/maxwshen/piu-annotate/artifacts/analysis/segment-difficulty.csv', index_col = 0)
df['pred level unpacked'] = [float(p[1:-1]) for p in df['pred level']]
df.head()
# Out:
#                                            shortname  max segment level  \
# 0                        Euphorianic_-_SHK_S3_ARCADE               2.74
# 1                           Accident_-_MAX_S7_ARCADE               8.63
# 2  Dual_Racing_RED_vs_BLUE_-_Nato_&_r300k_S11_ARCADE              11.96
# 3   Wedding_Crashers_-_SHORT_CUT_-_-_SHK_S4_SHORTCUT               4.44
# 4                   With_my_Lover_-_BanYa_D14_ARCADE              15.58
#
#                                       segment levels  chart level  \
# 0  [2.74, 2.69, 2.74, 1.89, 2.68, 1.76, 2.74, 2.6...            3
# 1         [1.76, 7.26, 7.16, 7.93, 7.26, 7.75, 8.63]            7
# 2  [6.48, 7.36, 11.73, 5.57, 7.72, 5.51, 7.64, 11...           11
# 3                             [3.2, 3.67, 3.3, 4.44]            4
# 4                  [10.5, 9.72, 10.15, 11.29, 15.58]           14
#
#       pred level     sord  pred level unpacked
# 0   [2.25500693]  singles             2.255007
# 1   [8.14666507]  singles             8.146665
# 2  [11.14022679]  singles            11.140227
# 3   [3.77640073]  singles             3.776401
# 4  [12.13289036]  doubles            12.132890

# %%
sns.scatterplot(
    data = df,
    x = 'chart level',
    y = 'pred level unpacked',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
sns.scatterplot(
    data = df,
    x = 'pred level unpacked',
    y = 'max segment level',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
sns.scatterplot(
    data = df,
    x = 'chart level',
    y = 'max segment level',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
df['max segment level - chart level'] = df['max segment level'] - df['chart level']

df.sort_values(by = 'max segment level - chart level', ascending = False)
# Out:
#                                               shortname  max segment level  \
# 1823                Another_Truth_-_Novasonic_D9_ARCADE              17.44
# 2875  The_People_didnt_know_Pumping_up_-_Banya_Produ...              14.09
# 3062                Good_Night_-_Dreamcatcher_D6_ARCADE              13.92
# 1990                   Baroque_Virus_-_Zircon_S5_ARCADE              12.85
# 2707  Move_That_Body_-_DM_Ashura_feat._Skizzo_&_Hann...              12.20
# ...                                                 ...                ...
# 342      Yeo_rae_a_-_SID-Sound_S13_INFOBAR_TITLE_ARCADE               7.00
# 3196                             Spray_-_WEi_D17_ARCADE              10.13
# 2999                            STAGER_-_Ras_S17_ARCADE              10.08
# 2068                            STAGER_-_Ras_D18_ARCADE              10.13
# 35                             Like_Me_-_SHK_S14_ARCADE               5.38
#
#                                          segment levels  chart level  \
# 1823             [16.83, 7.79, 17.44, 9.24, 9.04, 6.58]            9
# 2875  [5.74, 5.74, 14.09, 5.74, 5.36, 6.02, 5.8, 6.1...            6
# 3062              [13.92, 5.35, 6.53, 5.74, 5.35, 6.25]            6
# 1990  [3.62, 4.51, 3.15, 12.85, 4.04, 4.65, 3.64, 2.08]            5
# 2707   [3.61, 5.29, 4.59, 4.88, 4.49, 4.87, 4.84, 12.2]            5
# ...                                                 ...          ...
# 342            [5.31, 5.13, 4.98, 6.1, 6.09, 4.49, 7.0]           13
# 3196  [7.69, 8.88, 6.35, 8.97, 10.13, 10.07, 7.84, 8...           17
# 2999  [7.24, 4.91, 5.99, 5.99, 7.52, 6.81, 6.65, 10.08]           17
# 2068  [9.65, 6.51, 7.44, 7.58, 10.13, 7.8, 7.8, 7.91...           18
# 35    [3.52, 5.15, 5.19, 4.51, 5.38, 3.26, 5.14, 5.1...           14
#
#          pred level     sord  pred level unpacked  \
# 1823  [11.02560439]  doubles            11.025604
# 2875   [7.69503344]  doubles             7.695033
# 3062   [6.45571774]  doubles             6.455718
# 1990   [5.69217613]  singles             5.692176
# 2707   [5.03893445]  singles             5.038934
# ...             ...      ...                  ...
# 342    [8.66570928]  singles             8.665709
# 3196  [10.87314184]  doubles            10.873142
# 2999    [9.8720715]  singles             9.872072
# 2068  [10.74590617]  doubles            10.745906
# 35     [6.93371117]  singles             6.933711
#
#       max segment level - chart level
# 1823                             8.44
# 2875                             8.09
# 3062                             7.92
# 1990                             7.85
# 2707                             7.20
# ...                               ...
# 342                             -6.00
# 3196                            -6.87
# 2999                            -6.92
# 2068                            -7.87
# 35                              -8.62
#
# [3836 rows x 8 columns]

# %%
df.sort_values(by = 'max segment level - chart level', ascending = False).to_csv('sorted-segment-diff.csv')
