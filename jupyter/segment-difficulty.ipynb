# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv('/home/maxwshen/piu-annotate/artifacts/analysis/segment-difficulty.csv', index_col = 0)
# df['pred level float'] = [float(p[1:-1]) for p in df['pred level']]
df.head()
# Out:
#                                            shortname  max segment level  \
# 0                        Euphorianic_-_SHK_S3_ARCADE               2.81
# 1                           Accident_-_MAX_S7_ARCADE              10.53
# 2  Dual_Racing_RED_vs_BLUE_-_Nato_&_r300k_S11_ARCADE              11.17
# 3   Wedding_Crashers_-_SHORT_CUT_-_-_SHK_S4_SHORTCUT               4.15
# 4                   With_my_Lover_-_BanYa_D14_ARCADE              13.92
#
#                                       segment levels  chart level     sord
# 0  [2.81, 2.81, 2.81, 2.6, 2.81, 2.58, 2.81, 2.81...            3  singles
# 1         [2.2, 7.09, 6.93, 9.95, 2.74, 7.78, 10.53]            7  singles
# 2  [9.22, 7.46, 11.17, 6.78, 7.64, 7.38, 9.15, 11...           11  singles
# 3                            [2.9, 3.68, 3.69, 4.15]            4  singles
# 4                 [11.54, 11.5, 12.08, 12.01, 13.92]           14  doubles

# %%
sns.scatterplot(
    data = df,
    x = 'chart level',
    y = 'max segment level',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
df['max segment level - chart level'] = df['max segment level'] - df['chart level']

df.sort_values(by = 'max segment level - chart level', ascending = False)
# Out:
#                                               shortname  max segment level  \
# 1243  Phantom_-Intermezzo-_-_Banya_Production_S7_ARCADE              15.51
# 2628                          Phantom_-_BanYa_S7_ARCADE              15.39
# 3320               Break_Out_-_Lunatic_Sounds_S4_ARCADE              10.97
# 3372             The_Devil_-_Banya_Production_S6_ARCADE              12.69
# 1996             Conflict_-_Siromaru_+_Cranky_S6_ARCADE              12.63
# ...                                                 ...                ...
# 1266        Poseidon_-_SHORT_CUT_-_-_Quree_S11_SHORTCUT               7.38
# 2068                            STAGER_-_Ras_D18_ARCADE              14.25
# 992   The_End_of_the_World_ft._Skizzo_-_MonstDeath_S...              15.96
# 2999                            STAGER_-_Ras_S17_ARCADE              11.05
# 35                             Like_Me_-_SHK_S14_ARCADE               7.63
#
#                                          segment levels  chart level     sord  \
# 1243  [5.78, 4.08, 5.9, 4.5, 5.12, 6.89, 6.77, 15.51...            7  singles
# 2628              [3.92, 5.05, 4.13, 6.45, 6.91, 15.39]            7  singles
# 3320  [3.62, 3.88, 1.97, 3.79, 4.28, 4.26, 3.8, 3.79...            4  singles
# 3372   [4.07, 4.12, 4.8, 4.18, 4.49, 4.91, 5.97, 12.69]            6  singles
# 1996  [6.72, 6.62, 6.29, 3.11, 2.84, 12.63, 6.98, 6.85]            6  singles
# ...                                                 ...          ...      ...
# 1266                                 [7.21, 7.12, 7.38]           11  singles
# 2068  [12.06, 8.06, 7.7, 8.26, 12.37, 11.59, 11.59, ...           18  doubles
# 992       [5.98, 5.22, 14.73, 7.34, 11.5, 15.64, 15.96]           20  singles
# 2999   [8.0, 5.06, 6.52, 6.52, 8.02, 6.87, 6.87, 11.05]           17  singles
# 35    [4.87, 7.33, 7.63, 6.11, 6.65, 3.99, 7.34, 7.6...           14  singles
#
#       max segment level - chart level
# 1243                             8.51
# 2628                             8.39
# 3320                             6.97
# 3372                             6.69
# 1996                             6.63
# ...                               ...
# 1266                            -3.62
# 2068                            -3.75
# 992                             -4.04
# 2999                            -5.95
# 35                              -6.37
#
# [3836 rows x 6 columns]

# %%
sns.ecdfplot(df['max segment level - chart level'])
# Out:
# <Axes: xlabel='max segment level - chart level', ylabel='Proportion'>

# %%
df.sort_values(by = 'max segment level - chart level', ascending = False).to_csv('sorted-segment-diff.csv')
