# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv('/home/maxwshen/piu-annotate/artifacts/analysis/segment-difficulty.csv', index_col = 0)
df['pred level float'] = [float(p[1:-1]) for p in df['pred level']]
df.head()
# Out:
#                                            shortname  max segment level  \
# 0                        Euphorianic_-_SHK_S3_ARCADE               2.75
# 1                           Accident_-_MAX_S7_ARCADE               8.50
# 2  Dual_Racing_RED_vs_BLUE_-_Nato_&_r300k_S11_ARCADE              11.48
# 3   Wedding_Crashers_-_SHORT_CUT_-_-_SHK_S4_SHORTCUT               4.10
# 4                   With_my_Lover_-_BanYa_D14_ARCADE              13.36
#
#                                       segment levels  chart level  \
# 0  [2.75, 2.74, 2.75, 2.2, 2.74, 2.22, 2.75, 2.74...            3
# 1            [5.42, 8.1, 8.1, 8.13, 5.65, 8.43, 8.5]            7
# 2  [8.23, 8.95, 11.48, 7.94, 9.31, 8.14, 8.92, 11...           11
# 3                            [2.95, 3.29, 3.29, 4.1]            4
# 4                [12.18, 12.48, 12.56, 12.68, 13.36]           14
#
#       pred level     sord  pred level float
# 0    [2.4576808]  singles          2.457681
# 1   [8.14906902]  singles          8.149069
# 2  [11.25962619]  singles         11.259626
# 3   [3.93873145]  singles          3.938731
# 4  [12.62090703]  doubles         12.620907

# %%
sns.scatterplot(
    data = df,
    x = 'chart level',
    y = 'pred level float',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
sns.scatterplot(
    data = df,
    x = 'pred level float',
    y = 'max segment level',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
sns.scatterplot(
    data = df,
    x = 'chart level',
    y = 'max segment level',
    alpha = 0.6,
)
sns.despine()
plt.grid(alpha = 0.2)

# %%
df['max segment level - chart level'] = df['max segment level'] - df['chart level']

df.sort_values(by = 'max segment level - chart level', ascending = False)
# Out:
#                                            shortname  max segment level  \
# 3372          The_Devil_-_Banya_Production_S6_ARCADE              10.89
# 3782                     Achluoias_-_D_AAN_S9_ARCADE              12.36
# 1451  Super_Fantasy_-_SHORT_CUT_-_-_SHK_D17_SHORTCUT              19.84
# 3480   Will-O-The-Wisp_-_BanYa_D14_HALFDOUBLE_ARCADE              16.81
# 2525           Final_Audition_Ep.1_-_BanYa_S9_ARCADE              11.80
# ...                                              ...                ...
# 1698              Amor_Fati_-_Yeon_Ja_Kim_S15_ARCADE              12.18
# 342   Yeo_rae_a_-_SID-Sound_S13_INFOBAR_TITLE_ARCADE              10.12
# 2999                         STAGER_-_Ras_S17_ARCADE              13.35
# 2068                         STAGER_-_Ras_D18_ARCADE              14.17
# 35                          Like_Me_-_SHK_S14_ARCADE               9.90
#
#                                          segment levels  chart level  \
# 3372  [4.04, 4.53, 4.57, 4.55, 4.76, 4.75, 4.76, 10.89]            6
# 3782        [8.71, 10.23, 10.4, 7.48, 8.57, 12.36, 7.5]            9
# 1451                              [11.61, 18.76, 19.84]           17
# 3480                [14.69, 15.74, 16.81, 14.35, 15.88]           14
# 2525         [7.54, 8.66, 9.34, 11.8, 11.8, 9.23, 9.53]            9
# ...                                                 ...          ...
# 1698   [11.98, 11.78, 12.1, 11.77, 12.03, 12.18, 11.67]           15
# 342                [9.73, 9.2, 9.78, 9.79, 9.07, 10.12]           13
# 2999  [11.43, 6.59, 10.76, 10.76, 11.79, 11.34, 11.3...           17
# 2068  [14.04, 11.18, 11.22, 11.22, 14.17, 12.79, 12....           18
# 35    [8.5, 9.02, 9.77, 9.34, 9.9, 7.68, 9.74, 9.77,...           14
#
#          pred level     sord  pred level float  \
# 3372  [10.13392436]  singles         10.133924
# 3782  [11.83999958]  singles         11.840000
# 1451  [19.00518101]  doubles         19.005181
# 3480  [16.99280748]  doubles         16.992807
# 2525  [11.36783331]  singles         11.367833
# ...             ...      ...               ...
# 1698  [12.35895343]  singles         12.358953
# 342    [8.48194097]  singles          8.481941
# 2999  [10.12506119]  singles         10.125061
# 2068  [11.19523971]  doubles         11.195240
# 35     [6.81796628]  singles          6.817966
#
#       max segment level - chart level
# 3372                             4.89
# 3782                             3.36
# 1451                             2.84
# 3480                             2.81
# 2525                             2.80
# ...                               ...
# 1698                            -2.82
# 342                             -2.88
# 2999                            -3.65
# 2068                            -3.83
# 35                              -4.10
#
# [3836 rows x 8 columns]

# %%
sns.ecdfplot(df['max segment level - chart level'])
# Out:
# <Axes: xlabel='max segment level - chart level', ylabel='Proportion'>

# %%
df.sort_values(by = 'max segment level - chart level', ascending = False).to_csv('sorted-segment-diff.csv')
